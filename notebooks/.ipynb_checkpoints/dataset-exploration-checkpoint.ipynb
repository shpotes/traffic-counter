# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../data/train_labels.csv')
test = pd.read_csv('../data/train_labels.csv')

# %%
train.name.value_counts().plot(kind='bar')

# %%
test.name.value_counts().plot(kind='bar')

# %%
train.width.plot(kind='hist', bins=30)

# %%
train.height.plot(kind='hist', bins=30)

# %%
(train.height / train.width).plot(kind='hist', bins=30)
